# %%
#program to accept 2 dictionaries,merge 2 dictionaries and  display it.
dic1 = {}
roll1 = int(input("Enter roll no 1: "))
name1 = input("Enter name 1: ")
dic1[roll1] = name1
roll2 = int(input("Enter roll no 2: "))
name2 = input("Enter name 2: ")
dic1[roll2] = name2
roll3 = int(input("Enter roll no 3: "))
name3 = input("Enter name 3: ")
dic1[roll3] = name3
dic2 = {}
roll4 = int(input("Enter roll no 4: "))
name4 = input("Enter name 4: ")
dic2[roll4] = name4
roll5 = int(input("Enter roll no 5: "))
name5 = input("Enter name 5: ")
dic2[roll5] = name5
print("Original dictionary 1:", dic1)
print("Original dictionary 2:", dic2)
dic1.update(dic2)
print("Merged dictionary:", dic1)
# Out:
# Enter roll no 1:  101
# Enter name 1:  riya
# Enter roll no 2:  102
# Enter name 2:  miya
# Enter roll no 3:  103
# Enter name 3:  anu
# Enter roll no 4:  104
# Enter name 4:  fathi
# Enter roll no 5:  105
# Enter name 5:  siya
# Original dictionary 1: {101: 'riya', 102: 'miya', 103: 'anu'}
# Original dictionary 2: {104: 'fathi', 105: 'siya'}
# Merged dictionary: {101: 'riya', 102: 'miya', 103: 'anu', 104: 'fathi', 105: 'siya'}

# %%
#program to accept 5 students names&roll numbers and map these into a dictionary.sort the dictionary in ascending and descending order of their roll number
students={}
roll1=int(input("enter roll no 1:"))
name1=input("enter name 1:")
students[roll1]=name1
roll2=int(input("enter roll no 2:"))
name2=input("enter name 2:")
students[roll2]=name2
roll3=int(input("enter roll no 3:"))
name3=input("enter name 3:")
students[roll3]=name3
roll4=int(input("enter roll no 4:"))
name4=input("enter name 4:")
students[roll4]=name4
roll5=int(input("enter roll no 5:"))
name5=input("enter name 5:")
students[roll5]=name5
print("original dictionary:",students)
print("ascending order:",dict(sorted(students.items())))
print("descending order:",dict(sorted(students.items(),reverse=True)))
# Out:
# enter roll no 1: 101
# enter name 1: niya
# enter roll no 2: 102
# enter name 2: fiya
# enter roll no 3: 103
# enter name 3: riya
# enter roll no 4: 104
# enter name 4: tiya
# enter roll no 5: 105
# enter name 5: miya
# original dictionary: {101: 'niya', 102: 'fiya', 103: 'riya', 104: 'tiya', 105: 'miya'}
# ascending order: {101: 'niya', 102: 'fiya', 103: 'riya', 104: 'tiya', 105: 'miya'}
# descending order: {105: 'miya', 104: 'tiya', 103: 'riya', 102: 'fiya', 101: 'niya'}
