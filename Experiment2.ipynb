# %%
#converting celsius to farenheit
celsius=float(input("enter temparature in celsius:"))
fahrenheit=(celsius*9/5)+32
print("temparature in fahrenheit:",fahrenheit)
# Out:
# enter temparature in celsius:25
# temparature in fahrenheit: 77.0

# %%
kilometers=float(input("enter the distance in kilometers:")) 
miles=kilometers*0.621371 
print(f"Distance in miles:{miles:.2f}")
# Out:
# enter the distance in kilometers:23
# Distance in miles:14.29
